# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("cleaned_data.csv")

# %%
age_samples = np.array([])
age = data["age"]
print(age.head(2))
# Out:
# 0    45
# 1    28
# Name: age, dtype: int64

# %%
import random
data_samples = data.sample( n = 100, replace = False, random_state = 20)
for i in range(len(data_samples)):
    age = data_samples["age"]

print(data_samples)
# Out:
#       order_id        date customer_id customer_name  age gender   region  \
# 9957  ORD09958  2023-09-09    CUST0212        Suresh   18      M     East
# 1687  ORD01688  2023-08-02    CUST2586         Arjun   35      M    North
# 2116  ORD02117  2023-01-11    CUST0580        Nikhil   56      M    South
# 231   ORD00232  2022-10-09    CUST0142         Priya   57      F  Central
# 2780  ORD02781  2023-09-14    CUST1530          Ravi   33      M     East
# ...        ...         ...         ...           ...  ...    ...      ...
# 8281  ORD08282  2023-02-14    CUST0180         Meera   45      F     East
# 6690  ORD06691  2022-12-20    CUST2976           Dev   46      M  Central
# 1119  ORD01120  2022-09-09    CUST0415         Pooja   36      F     East
# 392   ORD00393  2022-01-16    CUST0912         Pooja   65      F    South
# 9514  ORD09515  2022-04-21    CUST2781          Ritu   45      F     East
#
#        category      product  quantity  unit_price  discount_pct  \
# ...
