# %%
from pickle import ADDITEMS

import seaborn as sns
import pandas as pd
from datetime import datetime,timedelta
import numpy as np

# %%
initial_time = datetime.strptime("7:30", "%H:%M")
lecture_duration = timedelta(hours = 1,minutes = 50)
num_slots = 10
slots = [ initial_time + lecture_duration * i for i in range(num_slots) ]
lecture_hours = np.array([slot.strftime("%H:%M") for slot in slots])

# %%
time_table = pd.DataFrame(
    columns = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
    index = lecture_hours
)

# %%
def add_activity( day, time, activity):
    time_table.loc[day][time] = activity

def delete_activity(day, time, activity):
    pass

def verify_attendance():
    pass

# %%
time_table.fillna(value="", inplace=True)
#print(time_table)
# Out:
#       Monday Tuesday Wednesday Thursday Friday Saturday Sunday
# 07:30
# 09:20
# 11:10
# 13:00
# 14:50
# 16:40
# 18:30
# 20:20
# 22:10
# 00:00

# %%
add_activity("Monday","07:30","IP(SMCS)")
print(time_table)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
